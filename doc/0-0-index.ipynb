# %% [markdown]
# # Python für Mathematiker
#
# ## Intro
#
# Dieses Skript ist eine Einführung in die Programmiersprache [Python](http://www.python.org),
# mit einem Fokus auf naturwissenschaftlich/mathematische Inhalte und Anwendungen.

# %%
# %run res/index.py
mk_index()
# Out:
# <style>
# div.index > div {
# display: block;
# font-size: 135%;
# line-height: 140%;
# }
# div.index > div.minor {
# font-size: 125%;
# padding-left: 2em;
# }
# </style>
# <div class='index'>
#                     <div class='major'>
#                         §0 <a href='0-0-index.ipynb'>Intro: Python für Mathematiker</a>
#                     </div>
#                     <div class='major'>
#                         §1 <a href='1-0-einfuehrung.ipynb'>Python Kurzeinführung</a>
#                     </div>
#                     <div class='minor'>
#                         §1.1 <a href='1-1-programmieren.ipynb'>Was ist Programmieren?</a>
#                     </div>
#                     <div class='minor'>
#                         §1.2 <a href='1-2-ipython.ipynb'>IPython Notebook</a>
#                     </div>
#                     <div class='major'>
#                         §2 <a href='2-0-konzepte.ipynb'>Konzepte</a>
#                     </div>
# ...

# %% [markdown]
# ### Autor
#
# [Harald Schilly](http://harald.schil.ly)
#
# ### License Note
#
# All text, images, media and code examples are covered by
# [CC BY-SA 4.0 International](https://creativecommons.org/licenses/by-sa/4.0/).
#
# The only exception are full Python codefiles,
# where their License is either explained in their respective headers or in absence of that,
# defaults to [Apache 2.0](http://www.apache.org/licenses/LICENSE-2.0.html)

# %% [markdown]
# ## Tools und Bibliotheken
#
# Dieses Skript bezieht sich unter anderem auf folgende Software und Bibliotheken:
#
#
# <table>
# <tr><td>
# <a href="http://www.python.org"><img src="img/python-logo-generic.svg"  style="height: 50px"></a>
# </td><td>Python</td>
# </tr>
#
# <tr><td>
# <a href="http://ipython.org">
# <img alt="ipython" src="_static/images/ipython.png"  style="height: 50px"></a>
# </td>
# <td>
# IPython:
# Enhanced Interactive Console
# </td>
# </tr>
#
# <tr><td>
# <a href="http://numpy.scipy.org">
# <img src="_static/images/numpylogo_med.png" style="height: 50px"></a>
# </td>
# <td>
#   NumPy: Base N-dimensional array package
#   </td>
#   </tr>
# </table>
#
# <div id="softwarelist">
# <div>
# <a href="http://www.scipy.org">
#   <img alt="scipy" src="" width="64">
#  SciPy library:   Fundamental library for scientific computing
#   </a>
#   </div>
# <div>
# <a href="http://matplotlib.org/">
#   <img alt="matplotlib" src="Matplotlib_logo.svg" style="height: 50px">
# Matplotlib:   Comprehensive 2D/3D Plotting  </a>
# </div>
# <div>
# <a href="http://statsmodels.sourceforge.net/">
# <img src="img/statsmodels_hybi_banner.png" style="height: 50px"/></a>
# </div>
# <div>
# <a href="http://scikit-learn.org/">
# <img src="img/scikit-learn-logo.png"  style="height: 50px"/></a>
# </div>
# <div>
# <a href="http://sympy.org/">
# <img alt="sympy" src="_static/images/sympy_logo.png"  style="height: 50px">
# Sympy:   Symbolic mathematics</a>
# </div>
# <div>
# <a href="http://pandas.pydata.org/">
# <img alt="pandas badge" src="_static/images/pandas_badge2.jpg"  style="height: 50px">
# pandas: Data structures &amp; analysis</a>
# </div>
# <div>
# <a href="http://rpy2.sourceforge.org/">
# <img alt="sympy" src="res/rpy2_logo.png"  style="height: 50px">
# Rpy2</a>
# </div>
# <div>
# <a href="http://www.sagemath.org"><img src="img/sage_logo_new_l_hc_edgy-nq8.png" style="height: 50px">
# Sage: open-source mathematical software system</a>
# </div>
# </div>
#
#
# <style type="text/css">
# div#softwarelist {    text-align: left; }
# div#softwarelist > div { padding: 50px; }
# div#softwarelist .rendered_html img { display: inline; }
# div#softwarelist > a { display: block; }
# </style>
